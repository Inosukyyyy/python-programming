# %% [markdown]
# Q1

# %%
class student:
    school_name = "upes"

    def __iniT__(self,name,age):
        self.name = name
        self.age = age

s1=student("tanveer", 20)
s2=student("ashish", 18)

print("school of student 1:", s1.school_name)
print("school of student 2:", s2.school_name)

print("name of student1: (s1.name), age: (s1.age)")
print("name of student2: (s2.name), age: (s2.age)")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       5         self.name = name
#       6         self.age = age
# ----> 8 s1=student("tanveer", 20)
#       9 s2=student("ashish", 18)
#      11 print("school of student 1:", s1.school_name)
#
# TypeError: student() takes no arguments
