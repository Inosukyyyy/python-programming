# %% [markdown]
# # CHAPTER 5

# %%
class student:
    def set_details(self, name, roll):
        self.name = name
        self.roll = roll

    def display(self):
        print(self.name, self.roll)

s1 = student()
s1.set_details("Aman", 101)
s1.display()
# Out:
# Aman 101
